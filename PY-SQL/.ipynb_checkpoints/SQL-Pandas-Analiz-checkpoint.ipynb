# %%
import pandas as pd
import numpy as np
import matplotlib as plt


import pyodbc
import pandas.io.sql
from textblob import TextBlob

# %%
### Parameters
server = 'DESKTOP-V7B8HFS\CINARBILISIM'
db = 'TwitterDB'

# Create the connection
conn = pyodbc.connect('DRIVER={SQL Server};SERVER=DESKTOP-V7B8HFS\CINARBILISIM; DATABASE=TwitterDB;Trusted_Connection=yes')
# query db

sql = "select  from_user from Tweet_import"
#sql1="SELECT       id_str, from_user, text, created_at, time, geo_coordinates, user_lang, from_user_id_str, user_followers_count, user_friends_count, user_location FROM            Memurlar "
#

# %%
  #  for fld in cursor2.columns(rows.Tweet_import.decode('utf-16-le')):

# %%
df = pandas.io.sql.read_sql(sql, conn)

# %%
df.head(10)

# %%
csv = pd.read_csv('C:/Users/sc977/Downloads/twitter/k/VatanEldenGidiyor.csv')

# %%
csv["text"]
# Out:
# 0       RT @ATAKIZI__: Bu mülteci , 10 TL karşılığında...
# 1       RT @siginmacisorunu: Ankara Altındağ Önder Mah...
# 2       RT @TurkDnya: "Ey Türk! Bu vatan ya senindir, ...
# 3       RT @siginmacisorunu: Altındağ'da Suriyelilerin...
# 4       @atabenli BİR MİKTAR PARAYA İHTIYACIM VAR\nPAP...
#                               ...
# 2965    RT @siginmacisorunu: Altındağ'dan yeni görüntü...
# 2966    RT @ozcainlkc: Daha düne kadar suriyeli çocukl...
# 2967    RT @drkaanyl: Altındağ'da yaşananlar, yaşanaca...
# 2968    RT @pinarmasal: Içimizden geçenleri çok güzel ...
# 2969    RT @Sonsuzluk__1938: Benim; Pakistanlı, Afgani...
# Name: text, Length: 2970, dtype: object

# %%
txt = "welcome to the jungle"

x = txt.split()

print(x)

# %%
m = deneme ["text"]
for i in m:
    print (len(i))
# Out:
# 219
# 103
# 103
# 118
# 243
# 196
# 123
# 106
# 138
# 217
# 148
# 321
# 138
# 320
# 87
# 221
# 120
# 123
# 201
# 42
# 318
# 294
# 239
# 109
# 43
# 279
# 254
# 287
# 168
# 201
# 293
# 148
# 134
# 294
# 115
# 116
# 235
# 245
# 29
# 278
# 138
# 33
# 189
# 267
# 277
# 144
# 255
# 126
# 133
# 277
# 277
# 99
# 195
# 240
# 158
# 207
# 150
# 278
# 166
# 189
# 207
# 188
# 64
# 247
# 84
# 196
# 98
# 280
# 238
# 126
# 268
# 267
# 57
# 167
# 142
# 270
# 237
# 99
# 259
# 321
# 138
# 149
# 85
# 138
# 145
# 238
# 138
# 239
# 130
# 96
# 267
# 118
# 217
# 277
# 149
# 247
# 115
# 67
# 294
# 221
# 91
# 113
# 256
# 95
# 53
# 99
# 200
# 120
# 99
# 96
# 158
# 139
# 148
# 313
# 172
# 157
# 318
# 227
# 261
# 322
# 145
# 217
# 264
# 161
# 257
# 307
# 292
# 154
# 189
# 322
# 267
# 144
# 267
# 164
# 154
# 63
# 99
# 238
# 99
# 62
# 144
# 254
# 113
# 267
# 277
# 238
# 276
# 245
# 279
# 190
# 237
# 124
# 317
# 267
# 103
# 99
# 79
# 196
# 221
# 201
# 260
# 133
# 113
# 200
# 152
# 238
# 159
# 185
# 292
# 108
# 113
# ...

# %%
yazi = "data science is one of the best paid professions "

blob = TextBlob(yazi)
blob_eng = blob.translate(to='tr')
blob_Hirvat = blob.translate(to='hr')
blob_Hind = blob.translate(to='hi')
blob_Ru = blob.translate(to='ru')

# %%
blob_eng, blob_Hirvat, blob_Hind, blob_Ru
# Out:
# (TextBlob("veri bilimi en iyi ücretli mesleklerden biridir"),
#  TextBlob("znanost o podacima jedno je od najbolje plaćenih zanimanja"),
#  TextBlob("डेटा साइंस सबसे अच्छे भुगतान वाले व्यवसायों में से एक है"),
#  TextBlob("наука о данных - одна из самых высокооплачиваемых профессий"))

# %%
poem = 'Послушайте! Ведь, если звезды зажигают - значит - это кому-нибудь нужно? Значит - кто-то хочет, чтобы они были? Значит - кто-то называет эти плевочки жемчужиной?'

blob = TextBlob(poem)
#print(blob.translate(to='tr'))
cevir=blob.translate(to='tr')

# %%
cevir
# Out:
# TextBlob("Dinlemek! Sonuçta, yıldızlar yanıyorsa, birinin buna ihtiyacı olduğu anlamına mı geliyor? Yani - biri olmalarını mı istiyor? Yani biri bu tükürüklere inci mi diyor?")
