# %%
import pandas as pd
import numpy as np
import matplotlib as plt


import pyodbc
import pandas.io.sql
from textblob import TextBlob

import googletrans

from googletrans import Translator
import locale
locale.setlocale(locale.LC_ALL, "tr_TR.utf-8")

import twitter

# %%
csv = pd.read_csv('C:/Users/sc977/Downloads/twitter/k/VatanEldenGidiyor.csv')

# %%
m=csv["text"], 
k=csv["entities_str"][0]

# %%
m
# Out:
# (0       RT @ATAKIZI__: Bu mülteci , 10 TL karşılığında...
#  1       RT @siginmacisorunu: Ankara Altındağ Önder Mah...
#  2       RT @TurkDnya: "Ey Türk! Bu vatan ya senindir, ...
#  3       RT @siginmacisorunu: Altındağ'da Suriyelilerin...
#  4       @atabenli BİR MİKTAR PARAYA İHTIYACIM VAR\nPAP...
#                                ...
#  2965    RT @siginmacisorunu: Altındağ'dan yeni görüntü...
#  2966    RT @ozcainlkc: Daha düne kadar suriyeli çocukl...
#  2967    RT @drkaanyl: Altındağ'da yaşananlar, yaşanaca...
#  2968    RT @pinarmasal: Içimizden geçenleri çok güzel ...
#  2969    RT @Sonsuzluk__1938: Benim; Pakistanlı, Afgani...
#  Name: text, Length: 2970, dtype: object,)

# %%
for i in m [0]['screen_name']:
    print(i)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-a599dcbea688> in <module>
# ----> 1 for i in m [0]['screen_name']:
#       2     print(i)
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     851
#     852         elif key_is_scalar:
# --> 853             return self._get_value(key)
#     854
#     855         if is_hashable(key):
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in _get_value(self, label, takeable)
#     959
#     960         # Similar to Index.get_value, but we do not fall back to positional
# --> 961         loc = self.index.get_loc(label)
#     962         return self.index._get_values_for_loc(self, loc, label)
#     963
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     352                 except ValueError as err:
# ...

# %%
csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2970 entries, 0 to 2969
# Data columns (total 18 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id_str                     2970 non-null   int64
#  1   from_user                  2970 non-null   object
#  2   text                       2970 non-null   object
#  3   created_at                 2970 non-null   object
#  4   time                       2970 non-null   object
#  5   geo_coordinates            0 non-null      float64
#  6   user_lang                  0 non-null      float64
#  7   in_reply_to_user_id_str    148 non-null    float64
#  8   in_reply_to_screen_name    148 non-null    object
#  9   from_user_id_str           2970 non-null   int64
#  10  in_reply_to_status_id_str  144 non-null    float64
#  11  source                     2970 non-null   object
#  12  profile_image_url          2970 non-null   object
# ...

# %%
csv.head()
# Out:
#                 id_str       from_user  \
# 0  1425574709559693313         oparlar
# 1  1425574708628672512  GunesimDogdumu
# 2  1425574708624437252  byoguzhanyldrn
# 3  1425574708234293250  Turk_1071_Turk
# 4  1425574708171399168         HMayDNS
#
#                                                 text  \
# 0  RT @ATAKIZI__: Bu mülteci , 10 TL karşılığında...
# 1  RT @siginmacisorunu: Ankara Altındağ Önder Mah...
# 2  RT @TurkDnya: "Ey Türk! Bu vatan ya senindir, ...
# 3  RT @siginmacisorunu: Altındağ'da Suriyelilerin...
# 4  @atabenli BİR MİKTAR PARAYA İHTIYACIM VAR\nPAP...
#
#                        created_at                 time  geo_coordinates  \
# 0  Wed Aug 11 21:47:51 +0000 2021  11/08/2021 22:47:51              NaN
# 1  Wed Aug 11 21:47:51 +0000 2021  11/08/2021 22:47:51              NaN
# 2  Wed Aug 11 21:47:51 +0000 2021  11/08/2021 22:47:51              NaN
# 3  Wed Aug 11 21:47:50 +0000 2021  11/08/2021 22:47:50              NaN
# ...

# %%
tweet_metni=[csv[text]
             for csv in durum_bilgisi]


kelime_listesi=[x
                for i in tweet_metni
                    for x in i.split()
    
    
    
]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-4ee89226fe7d> in <module>
#       1 tweet_metni=[csv[text]
# ----> 2              for csv in durum_bilgisi]
#       3
#       4
#       5 kelime_listesi=[x
#
# NameError: name 'durum_bilgisi' is not defined

# %%
from collections import Counter

for item in [m]:
    i = Counter(item)
    print(i.most_common()[:5])
    print()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-5f94e0687cfc> in <module>
#       1 from collections import Counter
#       2
# ----> 3 for item in [m]:
#       4     i = Counter(item)
#       5     print(i.most_common()[:5])
#
# NameError: name 'm' is not defined
